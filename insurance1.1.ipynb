# %% [markdown]
# Machine learning with pycaret module on python

# %% [markdown]
# resources:
# https://pycaret.gitbook.io/docs/get-started/tutorials
# https://colab.research.google.com/github/pycaret/pycaret/blob/master/tutorials/Tutorial%20-%20Regression.ipynb#scrollTo=87c1a007
# https://towardsdatascience.com/5-things-you-are-doing-wrong-in-pycaret-e01981575d2a

# %%
#pip install pycaret

# %%
# Import dataset from pycaret repository
from pycaret.datasets import get_data
data = get_data('insurance')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# import pycaret regression and init setup
from pycaret.regression import *
s = setup(data, target = 'charges', session_id = 123)
# Out:
# <style type="text/css">
# #T_09f70_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_09f70">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09f70_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_09f70_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09f70_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_09f70_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_09f70_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_09f70_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_09f70_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_09f70_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_09f70_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# import RegressionExperiment and init the class
from pycaret.regression import RegressionExperiment
exp = RegressionExperiment()

# check the type of exp
type(exp)
# Out:
# pycaret.regression.oop.RegressionExperiment

# %%
# init setup on exp
exp.setup(data, target = 'charges', session_id = 123)
# Out:
# <style type="text/css">
# #T_f7219_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f7219">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7219_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f7219_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7219_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f7219_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f7219_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f7219_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f7219_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f7219_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_f7219_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# compare baseline models
best = compare_models()
# Out:
# <style type="text/css">
# #T_780e7 th {
#   text-align: left;
# }
# ...

# %%
#not using the best because of run time. May use gradient boosting when there is time.

# %%
#best = create_model('gbr') #choose gradient boosting regressor (gbr) #to avoid plot errors with some models

# %%
best = create_model('lr') #choose lr to run quickly and plot errors with some models

# %% [markdown]
# ### Analyze Model

# %%
# plot residuals
plot_model(best, plot = 'residuals')

# %%
# plot error
plot_model(best, plot = 'error')

# %%
# plot feature importance
plot_model(best, plot = 'feature')

# %% [markdown]
# ## Prediction
# The `predict_model` function returns `prediction_label` as new column to the input dataframe. When data is `None` (default), it uses the test set (created during the setup function) for scoring.
